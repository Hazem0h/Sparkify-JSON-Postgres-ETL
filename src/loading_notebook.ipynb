# %%
import os
import glob
import psycopg2
import pandas as pd
import numpy as np
import json
import sql_queries
from typing import List

# %% [markdown]
# Connecting to the database

# %%
with open("../config.json") as f:
    config = json.load(f)
    
conn = psycopg2.connect(host = config["host"],
                        dbname = config["dbname"],
                        user = config["username"],
                        password = config["password"])

conn.set_session(autocommit=True)
cur = conn.cursor()

# %% [markdown]
# # Order of table filling
# Due to the foreign Key constraints, we will need to insert the data in a certain order
# * Artists need to be inserted before songs
# * All dimension tables need to be filled before the fact table
#
# An order that satisfied these constraints can be:
# 1. Artist table
# 2. Song table
# 3. User table
# 4. Time table
# 5. Songplay table

# %% [markdown]
# ## 1. The artist table

# %%
df_artist = pd.read_csv("../data/cleaned/artists.csv")
df_artist.head()
# Out:
#             artist_id       artist_name  artist_location  artist_longitude  \
# 0  ARD7TVE1187B99BFB1            Casual  California - LA               NaN
# 1  ARMJAGH1187FB546F3      The Box Tops      Memphis, TN         -90.04892
# 2  ARKRRTF1187B9984DA  Sonora Santanera              NaN               NaN
# 3  AR7G5I41187FB4CE6C          Adam Ant  London, England               NaN
# 4  ARXR32B1187FB57099               Gob              NaN               NaN
#
#    artist_latitude
# 0              NaN
# 1         35.14968
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# * It's important to note that np.nan is a float value, and doesn't automatically translate to `NULL` in the database.
#
# For example,

# %%
cur.execute(sql_queries.artist_table_insert, list(df_artist.iloc[2].values))

# %%
cur.execute("SELECT * FROM artist")
res = cur.fetchone()
print(res)
print(type(res[-1]))
# Out:
# ('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', None, None)
# <class 'NoneType'>

# %% [markdown]
# * So, the values stored in the database are not `NULL`.
# * This can cause confusion when we later fetch data from the database.
# * We should standardize the way we represent NULLs

# %%
df_artist.fillna(psycopg2.extensions.AsIs("NULL"), inplace = True)

# %%
cur.execute("DELETE FROM artist")
cur.execute(sql_queries.artist_table_insert, list(df_artist.iloc[2].values))
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 cur.execute("DELETE FROM artist")
#       2 cur.execute(sql_queries.artist_table_insert, list(df_artist.iloc[2].values))
#
# ForeignKeyViolation: update or delete on table "artist" violates foreign key constraint "song_artist_id_fkey" on table "song"
# DETAIL:  Key (artist_id)=(ARD7TVE1187B99BFB1) is still referenced from table "song".

# %%
cur.execute("SELECT * FROM artist")
res = cur.fetchone()
print(res)
# Out:
# ('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', None, None)

# %% [markdown]
# ## 2. Songs table

# %%
df_songs = pd.read_csv("../data/cleaned/songs.csv")
df_songs.head()
# Out:
#               song_id             title           artist_id   duration    year
# 0  SOMZWCG12A8C13C480  I Didn't Mean To  ARD7TVE1187B99BFB1  218.93179     NaN
# 1  SOCIWDW12A8C13D406         Soul Deep  ARMJAGH1187FB546F3  148.03546  1969.0
# 2  SOXVLOJ12AB0189215   Amor De Cabaret  ARKRRTF1187B9984DA  177.47546     NaN
# 3  SONHOTT12A8C13493C   Something Girls  AR7G5I41187FB4CE6C  233.40363  1982.0
# 4  SOFSOCN12A8C143F5D    Face the Ashes  ARXR32B1187FB57099  209.60608  2007.0

# %%
df_songs.fillna(psycopg2.extensions.AsIs("NULL"), inplace = True)

# %%
cur.execute(sql_queries.song_table_insert, list(df_songs.iloc[2].values))
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 cur.execute(sql_queries.song_table_insert, list(df_songs.iloc[2].values))
#
# UniqueViolation: duplicate key value violates unique constraint "song_pkey"
# DETAIL:  Key (song_id)=(SOXVLOJ12AB0189215) already exists.

# %%
cur.execute("SELECT * FROM song")
res = cur.fetchone()
print(res)
# Out:
# ('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 219, None)

# %% [markdown]
# ## 3. The time table

# %%
df_times = pd.read_csv("../data/cleaned/time.csv")
df_times.head()
# Out:
#               ts  hour  day  weekday  week  month  year
# 0  1541105830796    20    1        3    44     11  2018
# 1  1541106106796    21    1        3    44     11  2018
# 2  1541106132796    21    1        3    44     11  2018
# 3  1541106352796    21    1        3    44     11  2018
# 4  1541106496796    21    1        3    44     11  2018

# %%
df_times.fillna(psycopg2.extensions.AsIs("NULL"), inplace = True)

# %%
cur.execute(sql_queries.time_table_insert, list(df_times.iloc[0].values))
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 cur.execute(sql_queries.time_table_insert, list(df_times.iloc[0].values))
#
# ProgrammingError: can't adapt type 'numpy.int64'

# %% [markdown]
# * It looks like psycopg2 doesn't understand how to convert `np.int64` types to sql.
# * As such, we will have to use something called `adapter`. It's a psycopg2 object through which we can tell pycopg2 how to translate certain values to SQL.
#
# I learned that from this [stackoverflow post](https://stackoverflow.com/questions/50626058/psycopg2-cant-adapt-type-numpy-int64)

# %%
from psycopg2.extensions import register_adapter
def adapt_np_int(np_int:np.int64):
    _INT = psycopg2.extensions.Int
    return _INT(np_int)
    
register_adapter(np.int64, adapt_np_int)

# %%
cur.execute(sql_queries.time_table_insert, list(df_times.iloc[0].values))
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 cur.execute(sql_queries.time_table_insert, list(df_times.iloc[0].values))
#
# ProgrammingError: can't adapt type 'numpy.int64'

# %%
cur.execute("SELECT * FROM time_table")
res = cur.fetchone()
print(res)
# Out:
# (1541105830796, 20, 1, 3, 44, 11, 2018)

# %% [markdown]
# ## 4. User Data

# %%
df_users = pd.read_csv("../data/cleaned/users.csv")
df_users.head()
# Out:
#    userId firstName  lastName gender level
# 0     2.0   Jizelle  Benjamin      F  free
# 1     3.0     Isaac    Valdez      M  free
# 2     4.0    Alivia   Terrell      F  free
# 3     5.0    Elijah     Davis      M  free
# 4     6.0   Cecilia     Owens      F  free

# %%
df_users.fillna(psycopg2.extensions.AsIs("NULL"), inplace = True)

# %%
cur.execute(sql_queries.user_table_insert, list(df_users.iloc[0].values))

# %%
cur.execute("SELECT * FROM user_table")
res = cur.fetchone()
print(res)
# Out:
# (3, 'Isaac', 'Valdez', 'M', 'free')

# %% [markdown]
# ## 5. The songplay table

# %%
df_songplays = pd.read_csv("../data/cleaned/songplays.csv")
df_songplays.head()
# Out:
#    sessionId             ts                          song     length  \
# 0        139  1541106106796                  You Gotta Be  246.30812
# 1        139  1541106352796                       Flat 55  144.03873
# 2        139  1541106496796  Quem Quiser Encontrar O Amor  177.18812
# 3        139  1541106673796                     Eriatarka  380.42077
# 4        139  1541107053796               Becoming Insane  440.26730
#
#               artist  userId level                     location  \
# 0            Des'ree     8.0  free  Phoenix-Mesa-Scottsdale, AZ
# 1            Mr Oizo     8.0  free  Phoenix-Mesa-Scottsdale, AZ
# 2         Tamba Trio     8.0  free  Phoenix-Mesa-Scottsdale, AZ
# 3     The Mars Volta     8.0  free  Phoenix-Mesa-Scottsdale, AZ
# 4  Infected Mushroom     8.0  free  Phoenix-Mesa-Scottsdale, AZ
#
#                                            userAgent
# 0  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 1  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 2  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 3  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 4  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...

# %%
for index, row in df_songplays.iterrows():

    # get songid and artistid from song and artist tables
    cur.execute(sql_queries.song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None

    #print((row["ts"], row["userId"], row["level"], songid, artistid, row["sessionId"], row["location"], row["userAgent"]))
    # insert songplay record
    songplay_data = (row["ts"], row["userId"], row["level"], songid, artistid, row["sessionId"], row["location"], row["userAgent"])
    cur.execute(sql_queries.songplay_table_insert, songplay_data)

# %% [markdown]
# So, that's a violation of the foreign key constraint, because we haven't filled the dimension tables yet. That'll be done in the script.
#
# That's it for this notebook!

# %% [markdown]
# N.B: I would say we could do our joins only once in pandas instead of doing table joins (`song_select`) for EACH entry in the songplay table. That would be more efficient.

# %%
songs_artists = df_songs.merge(df_artist, on = "artist_id")[["title", "artist_name", "song_id", "artist_id", "duration"]]
songs_artists.head()
# Out:
#               title       artist_name             song_id           artist_id  \
# 0  I Didn't Mean To            Casual  SOMZWCG12A8C13C480  ARD7TVE1187B99BFB1
# 1           OAKtown            Casual  SOQLGFP12A58A7800E  ARD7TVE1187B99BFB1
# 2         Soul Deep      The Box Tops  SOCIWDW12A8C13D406  ARMJAGH1187FB546F3
# 3   Amor De Cabaret  Sonora Santanera  SOXVLOJ12AB0189215  ARKRRTF1187B9984DA
# 4   Something Girls          Adam Ant  SONHOTT12A8C13493C  AR7G5I41187FB4CE6C
#
#     duration
# 0  218.93179
# 1  259.44771
# 2  148.03546
# 3  177.47546
# 4  233.40363

# %%
merged = df_songplays.merge(songs_artists, left_on = ["song", "artist", "length"], right_on = ["title", "artist_name", "duration"], how = "left")
merged
# Out:
#       sessionId             ts                                   song  \
# 0           139  1541106106796                           You Gotta Be
# 1           139  1541106352796                                Flat 55
# 2           139  1541106496796           Quem Quiser Encontrar O Amor
# 3           139  1541106673796                              Eriatarka
# 4           139  1541107053796                        Becoming Insane
# ...         ...            ...                                    ...
# 6815       1076  1543603205796                          The Pretender
# 6816       1076  1543603476796                        Besos De Ceniza
# 6817       1076  1543603678796                                   Rose
# 6818       1076  1543603884796                           The Haunting
# 6819        985  1543607664796  Anything You Say (Unreleased Version)
#
#          length             artist  userId level                     location  \
# 0     246.30812            Des'ree     8.0  free  Phoenix-Mesa-Scottsdale, AZ
# 1     144.03873            Mr Oizo     8.0  free  Phoenix-Mesa-Scottsdale, AZ
# 2     177.18812         Tamba Trio     8.0  free  Phoenix-Mesa-Scottsdale, AZ
# 3     380.42077     The Mars Volta     8.0  free  Phoenix-Mesa-Scottsdale, AZ
# 4     440.26730  Infected Mushroom     8.0  free  Phoenix-Mesa-Scottsdale, AZ
# ...         ...                ...     ...   ...                          ...
# 6815  271.38567       Foo Fighters    16.0  paid        Birmingham-Hoover, AL
# 6816  202.60526         Timbiriche    16.0  paid        Birmingham-Hoover, AL
# 6817  206.05342   A Perfect Circle    16.0  paid        Birmingham-Hoover, AL
# 6818  348.68200           Anberlin    16.0  paid        Birmingham-Hoover, AL
# 6819  237.68771          Deas Vail     5.0  free  Detroit-Warren-Dearborn, MI
#
#                                               userAgent title artist_name  \
# 0     "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...   NaN         NaN
# 1     "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...   NaN         NaN
# 2     "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...   NaN         NaN
# 3     "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...   NaN         NaN
# 4     "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...   NaN         NaN
# ...                                                 ...   ...         ...
# 6815  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...   NaN         NaN
# 6816  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...   NaN         NaN
# 6817  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...   NaN         NaN
# 6818  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...   NaN         NaN
# 6819  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...   NaN         NaN
#
#      song_id artist_id  duration
# 0        NaN       NaN       NaN
# 1        NaN       NaN       NaN
# 2        NaN       NaN       NaN
# 3        NaN       NaN       NaN
# 4        NaN       NaN       NaN
# ...      ...       ...       ...
# 6815     NaN       NaN       NaN
# 6816     NaN       NaN       NaN
# 6817     NaN       NaN       NaN
# 6818     NaN       NaN       NaN
# 6819     NaN       NaN       NaN
#
# [6820 rows x 14 columns]

# %%
merged[["ts", "userId", "level", "song_id", "artist_id", "sessionId", "location", "userAgent"]]
# Out:
#                  ts  userId level song_id artist_id  sessionId  \
# 0     1541106106796     8.0  free     NaN       NaN        139
# 1     1541106352796     8.0  free     NaN       NaN        139
# 2     1541106496796     8.0  free     NaN       NaN        139
# 3     1541106673796     8.0  free     NaN       NaN        139
# 4     1541107053796     8.0  free     NaN       NaN        139
# ...             ...     ...   ...     ...       ...        ...
# 6815  1543603205796    16.0  paid     NaN       NaN       1076
# 6816  1543603476796    16.0  paid     NaN       NaN       1076
# 6817  1543603678796    16.0  paid     NaN       NaN       1076
# 6818  1543603884796    16.0  paid     NaN       NaN       1076
# 6819  1543607664796     5.0  free     NaN       NaN        985
#
#                          location  \
# 0     Phoenix-Mesa-Scottsdale, AZ
# 1     Phoenix-Mesa-Scottsdale, AZ
# 2     Phoenix-Mesa-Scottsdale, AZ
# 3     Phoenix-Mesa-Scottsdale, AZ
# 4     Phoenix-Mesa-Scottsdale, AZ
# ...                           ...
# 6815        Birmingham-Hoover, AL
# 6816        Birmingham-Hoover, AL
# 6817        Birmingham-Hoover, AL
# 6818        Birmingham-Hoover, AL
# 6819  Detroit-Warren-Dearborn, MI
#
#                                               userAgent
# 0     "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 1     "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 2     "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 3     "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 4     "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# ...                                                 ...
# 6815  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 6816  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 6817  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 6818  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 6819  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
# [6820 rows x 8 columns]

# %% [markdown]
# And we would use this resulting dataframe directly.
